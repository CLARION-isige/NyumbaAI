# %%
from langchain.chat_models import init_chat_model
from langchain.agents import AgentType, initialize_agent 
from langchain.tools import Tool
from dotenv import load_dotenv
import os
from serpapi import GoogleSearch
from typing import List, Dict, Any

load_dotenv()

os.environ['GROQ_API_KEY'] = os.getenv("GROQ_API_KEY")

# %%
def search_houses(location: str) -> List[Dict[Any, Any]]:
    """
    Search for houses for sale in a specific location using Google Local Search.
    
    Args:
        location (str): The location to search houses in
        
    Returns:
        List[Dict]: List of local results containing house listings
        
    Raises:
        ValueError: If location is empty or invalid
        Exception: For API or search related errors
    """
    try:
        # Input validation
        if not location or not isinstance(location, str):
            raise ValueError("Location must be a non-empty string")

        # Get the API key from environment variable for security
        serp_api_key = os.getenv('SERP_API_KEY')
        if not serp_api_key:
            raise ValueError("SERP_API_KEY environment variable not set")
            
        params = {
            "engine": "google_local",
            "q": "Houses for sale",
            "location": location,
            "api_key": serp_api_key
        }

        # Create search instance and execute search
        search = GoogleSearch(params)
        results = search.get_dict()
        local_results = results.get("local_results", [])
        
        if not local_results:
            print(f"No results found for houses in {location}")
            
        return local_results

    except Exception as e:
        print(f"An error occurred while searching houses: {str(e)}")
        return []

# Example usage
results = search_houses('Westlands, Nairobi')

# %%
results
# Out:
# [{'position': 1,
#   'rating': 5.0,
#   'reviews': 7,
#   'reviews_original': '(7)',
#   'description': '"Beautiful state of the art modern home."',
#   'links': {'website': 'http://ukooafricahomes.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//UKOO+AFRICA+HOMES+KENYA%2F+HOUSES+FOR+SALE+KENYA%2F+PLOTS+FOR+SALE+KENYA,+PLUMS+LANE,+Ojijo+Rd,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f175b42537529:0x1bbd2f8d218b9833?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQICRAA&hl=en&gl=us'},
#   'place_id': '1998806092822059059',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=1998806092822059059&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2692817, 'longitude': 36.811264},
#   'title': 'UKOO AFRICA HOMES KENYA/ HOUSES FOR SALE KENYA/ PLOTS FOR SALE KENYA',
#   'type': 'Industrial real estate agency',
#   'address': 'Kenya',
#   'phone': '+254 768 543038',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 2,
#   'rating': 5.0,
#   'reviews': 2,
#   'reviews_original': '(2)',
#   'links': {'website': 'https://www.trisums.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//Trisums+Investments,+44322+Woodvale+Grove,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f1781175519c7:0xe5e75371642b3ce8?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIFRAA&hl=en&gl=us'},
#   'place_id': '16566301500782623976',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=16566301500782623976&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2645682, 'longitude': 36.804733},
#   'title': 'Trisums Investments',
#   'type': 'Real estate agency',
#   'years_in_business': '3+ years in business',
#   'address': '44322 Woodvale Grove',
#   'phone': '+254 721 321300',
#   'hours': 'Closed ⋅ Opens 9 AM Sat'},
#  {'position': 3,
#   'rating': 4.3,
#   'reviews': 3,
#   'reviews_original': '(3)',
#   'links': {'directions': 'https://www.google.com/maps/dir//EMM+CONSULT,+Studio+House,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f173b9f831481:0x85fb412d364b82e7?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIAhAA&hl=en&gl=us'},
#   'place_id': '9654381888639042279',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=9654381888639042279&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2690469, 'longitude': 36.811394},
#   'title': 'EMM CONSULT, Studio House',
#   'type': 'Real estate agency',
#   'years_in_business': '7+ years in business',
#   'address': 'Nairobi, Kenya',
#   'phone': '+254 733 448331',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 4,
#   'rating': 5.0,
#   'reviews': 6,
#   'reviews_original': '(6)',
#   'description': '"Luxurious properties listed on their website."',
#   'links': {'website': 'https://realtors.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//Realtors+in+Kenya:+Houses+For+Sale+in+Nairobi+%7C+Villas+For+Sale+in+Nairobi+%7C+Apartments+For+Sale+in+Nairobi,+Stanbank+House,+Moi+Ave,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f1784e003587b:0x6e0285d100dbd1f3?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIEhAA&hl=en&gl=us'},
#   'place_id': '7927045426834559475',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=7927045426834559475&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2843813, 'longitude': 36.825615},
#   'title': 'Realtors in Kenya: Houses For Sale in Nairobi | Villas For Sale in Nairobi | Apartments For Sale in Nairobi',
#   'type': 'Real estate agent',
#   'years_in_business': '3+ years in business',
#   'address': 'Stanbank House, Moi Ave',
#   'phone': '+254 735 825326',
#   'hours': 'Open 24 hours'},
#  {'position': 5,
#   'rating': 4.2,
#   'reviews': 105,
#   'reviews_original': '(105)',
#   'description': '"Good place w great houses for modern living"',
#   'links': {'website': 'https://www.pamgolding.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//Pam+Golding+Properties+Kenya,+Fortis+Tower,+Woodvale+Grove,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f176acda36495:0x1cbb7fce9969b22f?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIFBAA&hl=en&gl=us'},
#   'place_id': '2070388979020706351',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=2070388979020706351&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2647305, 'longitude': 36.804394},
#   'title': 'Pam Golding Properties Kenya',
#   'type': 'Real estate agency',
#   'years_in_business': '10+ years in business',
#   'address': 'Fortis Tower, Woodvale Grove',
#   'phone': '+254 20 2370090',
#   'hours': 'Closed ⋅ Opens 8:30 AM Mon'},
#  {'position': 6,
#   'rating': 5.0,
#   'reviews': 2,
#   'reviews_original': '(2)',
#   'description': '"Best services ever very proffesional & direct."',
#   'links': {'directions': 'https://www.google.com/maps/dir//PRP4%2B5MC+Nova+group+Real+Estate,+Parklands+Rd,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f17fd46eda1e3:0x2b93cec73c1e09d7?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIDxAA&hl=en&gl=us'},
#   'place_id': '3140080720309782999',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=3140080720309782999&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2645466, 'longitude': 36.806633},
#   'title': 'Nova group Real Estate',
#   'type': 'Industrial real estate agency',
#   'address': 'PRP4+5MC, Parklands Rd',
#   'phone': '+254 111 624710',
#   'hours': 'Open ⋅ Closes 12 AM'},
#  {'position': 7,
#   'rating': 5.0,
#   'reviews': 5,
#   'reviews_original': '(5)',
#   'links': {'website': 'https://avenuepropertycenterkenya.com/',
#    'directions': 'https://www.google.com/maps/dir//Avenue+Vista+Property+Center+-+Houses,+Land+%26+Plots+for+Sale+%26+Rent,+View+Park+Towers,+Utalii+St,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x88315e59555f04d5:0xf3562f33388be742?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIERAA&hl=en&gl=us'},
#   'place_id': '17534254096252135234',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=17534254096252135234&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2828012, 'longitude': 36.81607},
#   'title': 'Avenue Vista Property Center - Houses, Land & Plots for Sale & Rent',
#   'type': 'Commercial real estate agency',
#   'years_in_business': '10+ years in business',
#   'address': 'View Park Towers, Utalii St',
#   'phone': '+254 723 478224',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 8,
#   'rating': 5.0,
#   'reviews': 3,
#   'reviews_original': '(3)',
#   'description': '"Thank you for helping me get a townhouse in Lavington."',
#   'links': {'website': 'https://www.ogre.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//Oxford+Gate+Real+Estate,+2129+Office+Suite,+Muthithi+Rd,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x4bff4a3e410e53b:0xb274fe4fb2ba57ec?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIEBAA&hl=en&gl=us'},
#   'place_id': '12859182454304036844',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=12859182454304036844&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2704505, 'longitude': 36.81146},
#   'title': 'Oxford Gate Real Estate',
#   'type': 'Real estate agency',
#   'years_in_business': '5+ years in business',
#   'address': '2129 Office Suite, Muthithi Rd',
#   'phone': '+254 782 000648',
#   'hours': 'Closed ⋅ Opens 9 AM Sat'},
#  {'position': 9,
#   'rating': 5.0,
#   'reviews': 1,
#   'reviews_original': '(1)',
#   'links': {'website': 'https://masterways.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//PRP3%2BJFM+Masterways+Real+Estate+(Westlands+office),+Woodvale+Grove,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f1700780342ab:0x95e003e6b23b7e12?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIDhAA&hl=en&gl=us'},
#   'place_id': '10799636195802054162',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=10799636195802054162&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2634138, 'longitude': 36.803677},
#   'title': 'Masterways Real Estate (Westlands office)',
#   'type': 'Real estate agency',
#   'address': 'PRP3+JFM, Woodvale Grove',
#   'phone': '+254 719 779997',
#   'hours': 'Closed ⋅ Opens 9 AM Sat'},
#  {'position': 10,
#   'rating': 5.0,
#   'reviews': 1,
#   'reviews_original': '(1)',
#   'links': {'website': 'http://www.wakala.africa/',
#    'directions': 'https://www.google.com/maps/dir//PRJ5%2B5FH+Wakala+Real+Estate+Limited,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f1745df36bb39:0x986b6fb9f273cf1b?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIDRAA&hl=en&gl=us'},
#   'place_id': '10982994960700395291',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=10982994960700395291&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2695515, 'longitude': 36.808746},
#   'title': 'Wakala Real Estate Limited',
#   'type': 'Real estate agency',
#   'address': 'PRJ5+5FH',
#   'phone': '+254 742 789755',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 11,
#   'rating': 3.0,
#   'reviews': 1,
#   'reviews_original': '(1)',
#   'links': {'directions': 'https://www.google.com/maps/dir//PRJ6%2BXRR+chamber+of+real+estate+agents(CREA),+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f17d66fddb9a3:0x667a9ecc67a7bacd?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIDBAA&hl=en&gl=us'},
#   'place_id': '7384389139776912077',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=7384389139776912077&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2675, 'longitude': 36.812023},
#   'title': 'chamber of real estate agents(CREA)',
#   'type': 'Commercial real estate agency',
#   'years_in_business': '5+ years in business',
#   'address': 'PRJ6+XRR',
#   'phone': '+254 715 212215',
#   'hours': 'Closed ⋅ Opens 9 AM Sat'},
#  {'position': 12,
#   'rating': 4.8,
#   'reviews': 299,
#   'reviews_original': '(299)',
#   'description': '"Their Properties are real and have all the right paperwork."',
#   'links': {'website': 'https://www.optiven.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//Optiven+Limited+-+Real+Estate+Company+in+kenya,+Absa+Towers,+Market+St,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f112956961f27:0x66f707b1592587fc?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQICxAA&hl=en&gl=us'},
#   'place_id': '7419407369402419196',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=7419407369402419196&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2845052, 'longitude': 36.817818},
#   'title': 'Optiven Limited - Real Estate Company in kenya',
#   'type': 'Property investment company',
#   'address': 'Absa Towers, Market St',
#   'phone': '+254 790 300300',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 13,
#   'rating': 5.0,
#   'reviews': 1,
#   'reviews_original': '(1)',
#   'links': {'directions': 'https://www.google.com/maps/dir//Citylife+Real+Estate,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f11e6ee6951d9:0x23a7d717c41a3e74?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIAxAA&hl=en&gl=us'},
#   'place_id': '2569258609512431220',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=2569258609512431220&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2675, 'longitude': 36.812023},
#   'title': 'Citylife Real Estate',
#   'type': 'Real estate consultant',
#   'years_in_business': '3+ years in business',
#   'address': 'Nairobi, Kenya',
#   'phone': '+254 722 892232',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 14,
#   'rating': 5.0,
#   'reviews': 1,
#   'reviews_original': '(1)',
#   'description': '"It\'s a great experience working with you"',
#   'links': {'directions': 'https://www.google.com/maps/dir//Rhema+Real+Estate,+Lotus+Plaza,+Chiromo+Ln,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f3fe78df0f781:0xbe31c1d964ee646c?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQICBAA&hl=en&gl=us'},
#   'place_id': '13704948280510538860',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=13704948280510538860&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2679158, 'longitude': 36.81128},
#   'title': 'Rhema Real Estate',
#   'type': 'Real estate consultant',
#   'years_in_business': '3+ years in business',
#   'address': 'Lotus Plaza, Chiromo Ln',
#   'phone': '+254 711 634163',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 15,
#   'rating': 4.4,
#   'reviews': 12,
#   'reviews_original': '(12)',
#   'description': '"Maestro Homes, a genuine , amazing and luxurious real estate company."',
#   'links': {'website': 'https://maestrohomesltd.com/',
#    'directions': 'https://www.google.com/maps/dir//Maestro+Homes+Ltd+-Real+Estate+%26+Property+Developers,+Reliable+Towers,+4th+Floor+Mogotio+Rd,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f1762f0654ac9:0x73dc2884cd7c7406?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIExAA&hl=en&gl=us'},
#   'place_id': '8348592360086336518',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=8348592360086336518&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2665521, 'longitude': 36.809803},
#   'title': 'Maestro Homes Ltd -Real Estate & Property Developers',
#   'type': 'Commercial real estate agency',
#   'years_in_business': '3+ years in business',
#   'address': 'Reliable Towers, 4th Floor Mogotio Rd',
#   'phone': '+254 703 888222',
#   'hours': 'Closed ⋅ Opens 8 AM Sat'},
#  {'position': 16,
#   'rating': 4.8,
#   'reviews': 101,
#   'reviews_original': '(101)',
#   'description': '"Highly recommend to anyone looking to sell or rent."',
#   'links': {'website': 'http://www.coralpi.com/',
#    'directions': 'https://www.google.com/maps/dir//Coral+Property+International+Ltd,+Peponi+Plaza,+3rd+Floor+Mwanzi+Rd,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f176d58c1b0b5:0x5b29436cea256d1f?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIBBAA&hl=en&gl=us'},
#   'place_id': '6568855666560429343',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=6568855666560429343&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.256329, 'longitude': 36.802383},
#   'title': 'Coral Property International Ltd',
#   'type': 'Real estate agency',
#   'years_in_business': '10+ years in business',
#   'address': 'Peponi Plaza, 3rd Floor Mwanzi Rd',
#   'phone': '+254 710 891028',
#   'hours': 'Closed ⋅ Opens 9 AM Sat'},
#  {'position': 17,
#   'rating': 5.0,
#   'reviews': 1,
#   'reviews_original': '(1)',
#   'links': {'website': 'http://rubygrouprealtors.com/',
#    'directions': 'https://www.google.com/maps/dir//The+Ruby+Real+Estate,+Riversprings+Properties+Ltd+%2F+Villapoint+Company+Ltd,+S.K+offices+suit+B5,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f176a0beafe63:0x6c3bdeea1119fbef?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIBxAA&hl=en&gl=us'},
#   'place_id': '7799072276612774895',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=7799072276612774895&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2657104, 'longitude': 36.79809},
#   'title': 'The Ruby Real Estate',
#   'type': 'Real estate agency',
#   'years_in_business': '3+ years in business',
#   'address': 'Riversprings Properties Ltd / Villapoint Company Ltd, S.K offices suit B5',
#   'phone': '+254 799 555111',
#   'hours': 'Open 24 hours'},
#  {'position': 18,
#   'rating': 4.8,
#   'reviews': 16,
#   'reviews_original': '(16)',
#   'description': '"Definitely your go to real estate company.."',
#   'links': {'directions': 'https://www.google.com/maps/dir//Affordable+Houses+in+Kenya,+17380-00100+Nairobi,+00100+Muthithi+Rd,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f179a0e63d1ff:0x2583e455f50bc9b9?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIBRAA&hl=en&gl=us'},
#   'place_id': '2703255259186973113',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=2703255259186973113&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2673253, 'longitude': 36.80827},
#   'title': 'Affordable Houses in Kenya',
#   'type': 'Real estate agency',
#   'years_in_business': '5+ years in business',
#   'address': '17380-00100 Nairobi, 00100 Muthithi Rd',
#   'phone': '+254 728 122127',
#   'hours': 'Closed ⋅ Opens 7:45 AM Sat'},
#  {'position': 19,
#   'rating': 4.6,
#   'reviews': 12,
#   'reviews_original': '(12)',
#   'description': '"Honest and friendly staff."',
#   'links': {'website': 'http://www.citiscapevaluers.com/',
#    'directions': 'https://www.google.com/maps/dir//Citiscape+Valuers+%26+Estate+Agents,+Waiyaki+Wy,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f173fd3b39d17:0xf7465631bf7353ed?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIChAA&hl=en&gl=us'},
#   'place_id': '17818023747403338733',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=17818023747403338733&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.2700204, 'longitude': 36.807186},
#   'title': 'Citiscape Valuers & Estate Agents',
#   'type': 'Real estate agency',
#   'years_in_business': '10+ years in business',
#   'address': 'Waiyaki Wy',
#   'phone': '+254 707 252525',
#   'hours': 'Closed ⋅ Opens 8 AM Mon'},
#  {'position': 20,
#   'rating': 3.4,
#   'reviews': 10,
#   'reviews_original': '(10)',
#   'description': '"The house was well maintained, and any concerns were addressed promptly."',
#   'links': {'website': 'https://pinkhouse.co.ke/',
#    'directions': 'https://www.google.com/maps/dir//Pink+House+Management+Ltd,+Design+Centre,+Tausi+Rd,+Nairobi,+Kenya/data=!4m6!4m5!1m1!4e2!1m2!1m1!1s0x182f17d35769d94d:0xf8baecb28c96e8b1?sa=X&ved=2ahUKEwiworCNwvOMAxVuLVkFHXxTNgQQ48ADegQIBhAA&hl=en&gl=us'},
#   'place_id': '17922897918681344177',
#   'place_id_search': 'https://serpapi.com/search.json?device=desktop&engine=google_local&gl=us&google_domain=google.com&hl=en&location=Westlands%2C+Nairobi&ludocid=17922897918681344177&q=Houses+for+sale',
#   'gps_coordinates': {'latitude': -1.265924, 'longitude': 36.808712},
#   'title': 'Pink House Management Ltd',
#   'type': 'Real estate agency',
#   'years_in_business': '5+ years in business',
#   'address': 'Design Centre, Tausi Rd',
#   'phone': '+254 729 037964',
#   'hours': 'Closed ⋅ Opens 8:30 AM Mon'}]
